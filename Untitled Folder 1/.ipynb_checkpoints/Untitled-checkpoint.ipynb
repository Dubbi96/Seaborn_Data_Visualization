# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time

# %%
A = np.genfromtxt('./txt/1595658278.4133599.txt',dtype='str', delimiter = ' ')
A
# Out:
# array([['67.9841079711914', '494.5229797363281', 'car', '98.96'],
#        ['182.55709838867188', '362.0151672363281', 'car', '98.85'],
#        ['110.44434356689453', '414.5419921875', 'car', '98.62'],
#        ['147.30422973632812', '343.0152282714844', 'car', '98.53'],
#        ['116.0750961303711', '505.5048522949219', 'car', '98.0'],
#        ['165.80490112304688', '280.8399963378906', 'car', '97.58'],
#        ['25.502248764038086', '488.0943603515625', 'car', '97.47'],
#        ['203.70648193359375', '243.80841064453125', 'car', '96.03'],
#        ['18.536935806274414', '582.3565063476562', 'car', '90.18'],
#        ['154.64871215820312', '206.34732055664062', 'car', '85.99'],
#        ['458.2729797363281', '241.18312072753906', 'car', '82.82'],
#        ['183.34048461914062', '238.53912353515625', 'car', '82.29'],
#        ['67.98466491699219', '494.5208740234375', 'car', '98.96'],
#        ['182.54136657714844', '362.01947021484375', 'car', '98.84'],
# ...

# %%
nam = ['x', 'y', 'type', 'prediction']
df = pd.DataFrame(A , columns = nam)

# %%
df
# Out:
#                       x                  y type prediction
# 0      67.9841079711914  494.5229797363281  car      98.96
# 1    182.55709838867188  362.0151672363281  car      98.85
# 2    110.44434356689453     414.5419921875  car      98.62
# 3    147.30422973632812  343.0152282714844  car      98.53
# 4     116.0750961303711  505.5048522949219  car       98.0
# ..                  ...                ...  ...        ...
# 105  25.097219467163086  495.3152160644531  car      95.18
# 106  18.341331481933594  583.3334350585938  car       91.9
# 107  178.29344177246094  245.0370330810547  car      91.75
# 108  147.04818725585938  216.0412139892578  car      86.55
# 109   458.3316345214844   241.224365234375  car      86.31
#
# [110 rows x 4 columns]

# %%
ax = sns.scatterplot(x="x", y="y", data=df, legend = None, label = None)

# %%
b = time.localtime()
aa = plt.scatter(A[:,0],A[:,1])
aa = plt.axis('off')
plt.savefig('{0}_{1}.png'.format(b.tm_hour,b.tm_min))
plt.show()
